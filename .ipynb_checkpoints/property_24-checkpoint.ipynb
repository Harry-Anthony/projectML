# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
data = pd.read_json('house.json')

# %%
data
# Out:
#              price  Listing Number     Type of Property  \
# 0      R 8 688 900       105587790     Apartment / Flat
# 1      R 4 950 000       110916424                House
# 2      R 2 095 000       110654938                House
# 3              POA       110942334  Commercial Property
# 4      R 1 785 000       110929554                House
# ...            ...             ...                  ...
# 10119  R 2 800 000       110772651   Vacant Land / Plot
# 10120  R 5 700 000       110699878     Apartment / Flat
# 10121    R 450 000       110469066                House
# 10122    R 799 000       106775948     Apartment / Flat
# 10123    R 550 000       110654029     Apartment / Flat
#
#                                           Street Address       Listing Date  \
# 0                           20 Tyrwhitt Avenue, Rosebank      17 March 2020
# 1                             12 4th Ave, Parktown North   06 February 2022
# ...

# %%
df = data.copy()

# %%
df.shape
# Out:
# (10124, 527)

# %%
df.dtypes.value_counts()
# Out:
# object     512
# float64     14
# int64        1
# dtype: int64

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# price               0.000000
# Listing Number      0.000000
# Type of Property    0.000000
# Listing Date        0.000000
# Bathrooms           0.214243
#                       ...
# Braai Room 23       0.999901
# Braai Room 24       0.999901
# Braai Room 25       0.999901
# Braai Room 27       0.999901
# Garden 4            0.999901
# Length: 527, dtype: float64

# %%
df = df[df.columns[df.isna().sum()/df.shape[0] < 0.9]]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (10124, 36)

# %%
df
# Out:
#              price  Listing Number     Type of Property  \
# 0      R 8 688 900       105587790     Apartment / Flat
# 1      R 4 950 000       110916424                House
# 2      R 2 095 000       110654938                House
# 3              POA       110942334  Commercial Property
# 4      R 1 785 000       110929554                House
# ...            ...             ...                  ...
# 10119  R 2 800 000       110772651   Vacant Land / Plot
# 10120  R 5 700 000       110699878     Apartment / Flat
# 10121    R 450 000       110469066                House
# 10122    R 799 000       106775948     Apartment / Flat
# 10123    R 550 000       110654029     Apartment / Flat
#
#                                           Street Address       Listing Date  \
# 0                           20 Tyrwhitt Avenue, Rosebank      17 March 2020
# 1                             12 4th Ave, Parktown North   06 February 2022
# ...

# %%
df = df.drop(['Bedroom 1','Bedroom 2', 'Bedroom 3', 'Bathroom 1', 'Bathroom 2', 'Listing Date', 'Listing Number', 'Price per m²', 'Description', 'Lounges', 'Dining Rooms', 'Lifestyle', 'Domestic Rooms', 'Entrance Hall', 'Reception Rooms', 'Dining Room', 'Lounge', 'Nearby Public Transport', 'Street Address', 'Levies', 'Kitchens', 'Kitchen'], axis = 1)

# %%
df.shape
# Out:
# (10124, 14)

# %%
df
# Out:
#              price     Type of Property  Erf Size Floor Size Bedrooms  \
# 0      R 8 688 900     Apartment / Flat    188 m²     188 m²        3
# 1      R 4 950 000                House    679 m²     329 m²        4
# 2      R 2 095 000                House    990 m²     452 m²        4
# 3              POA  Commercial Property    992 m²    2207 m²      NaN
# 4      R 1 785 000                House       NaN        NaN        3
# ...            ...                  ...       ...        ...      ...
# 10119  R 2 800 000   Vacant Land / Plot   2.76 ha        NaN      NaN
# 10120  R 5 700 000     Apartment / Flat  2 028 m²     233 m²        2
# 10121    R 450 000                House    135 m²        NaN        2
# 10122    R 799 000     Apartment / Flat       NaN      54 m²      NaN
# 10123    R 550 000     Apartment / Flat       NaN        NaN        2
#
#                                                Bathrooms Rates and Taxes  \
# ...

# %%
df.dtypes.value_counts()
# Out:
# object    14
# dtype: int64

# %%
df = df.drop(['Security'], axis = 1)
df['Erf Size'] = df['Erf Size'].str.replace(' m²','')
df['price'] = df['price'].str.replace('R ', '')
df['Rates and Taxes'] = df['Rates and Taxes'].str.replace('R ', '')
df['Floor Size'] = df['Floor Size'].str.replace(' m²', '')

# %%
df
# Out:
#            price     Type of Property Erf Size Floor Size Bedrooms  \
# 0      8 688 900     Apartment / Flat      188        188        3
# 1      4 950 000                House      679        329        4
# 2      2 095 000                House      990        452        4
# 3            POA  Commercial Property      992       2207      NaN
# 4      1 785 000                House      NaN        NaN        3
# ...          ...                  ...      ...        ...      ...
# 10119  2 800 000   Vacant Land / Plot  2.76 ha        NaN      NaN
# 10120  5 700 000     Apartment / Flat    2 028        233        2
# 10121    450 000                House      135        NaN        2
# 10122    799 000     Apartment / Flat      NaN         54      NaN
# 10123    550 000     Apartment / Flat      NaN        NaN        2
#
#                                                Bathrooms Rates and Taxes  \
# 0                                                      3             NaN
# ...

# %%
df['Erf Size'].str.contains("ha").value_counts()
# Out:
# False    5934
# True       63
# Name: Erf Size, dtype: int64

# %%
dff = df.copy()

# %%
def replace_ha(n):
    if (n.str.contains('ha')):
        n.str.replace(' ha', '')
        return n * 10000
    else:
        return n

# %%
dff['Erf Size'] = dff['Erf Size'].map(replace_ha)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-cc8737d06a9c> in <module>
# ----> 1 dff['Erf Size'] = list(map(replace_ha, dff['Erf Size']))
#
# <ipython-input-55-d77afead930f> in replace_ha(n)
#       1 def replace_ha(n):
# ----> 2     if (n.str.contains('ha')):
#       3         n.str.replace(' ha', '')
#       4         return n * 10000
#       5     else:
#
# AttributeError: 'map' object has no attribute 'str'

# %%
dff
# Out:
#            price     Type of Property                            Erf Size  \
# 0      8 688 900     Apartment / Flat  <map object at 0x0000026193451C10>
# 1      4 950 000                House  <map object at 0x0000026193451C10>
# 2      2 095 000                House  <map object at 0x0000026193451C10>
# 3            POA  Commercial Property  <map object at 0x0000026193451C10>
# 4      1 785 000                House  <map object at 0x0000026193451C10>
# ...          ...                  ...                                 ...
# 10119  2 800 000   Vacant Land / Plot  <map object at 0x0000026193451C10>
# 10120  5 700 000     Apartment / Flat  <map object at 0x0000026193451C10>
# 10121    450 000                House  <map object at 0x0000026193451C10>
# 10122    799 000     Apartment / Flat  <map object at 0x0000026193451C10>
# 10123    550 000     Apartment / Flat  <map object at 0x0000026193451C10>
#
#       Floor Size Bedrooms                                          Bathrooms  \
# ...

# %%
df['Erf Size'].isna().sum()
# Out:
# 4127

# %%
df['Floor Size'].str.contains("ha").count()
# Out:
# 5297
